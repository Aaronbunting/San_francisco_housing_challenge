# %% [markdown]
# # Housing Rental Analysis for San Francisco
#
# In this challenge, your job is to use your data visualization skills, including aggregation, interactive visualizations, and geospatial analysis, to find properties in the San Francisco market that are viable investment opportunities.
#
# ## Instructions
#
# Use the `san_francisco_housing.ipynb` notebook to visualize and analyze the real-estate data.
#
# Note that this assignment requires you to create a visualization by using hvPlot and GeoViews. Additionally, you need to read the `sfo_neighborhoods_census_data.csv` file from the `Resources` folder into the notebook and create the DataFrame that you’ll use in the analysis.
#
# The main task in this Challenge is to visualize and analyze the real-estate data in your Jupyter notebook. Use the `san_francisco_housing.ipynb` notebook to complete the following tasks:
#
# * Calculate and plot the housing units per year.
#
# * Calculate and plot the average prices per square foot.
#
# * Compare the average prices by neighborhood.
#
# * Build an interactive neighborhood map.
#
# * Compose your data story.
#
# ### Calculate and Plot the Housing Units per Year
#
# For this part of the assignment, use numerical and visual aggregation to calculate the number of housing units per year, and then visualize the results as a bar chart. To do so, complete the following steps:
#
# 1. Use the `groupby` function to group the data by year. Aggregate the results by the `mean` of the groups.
#
# 2. Use the `hvplot` function to plot the `housing_units_by_year` DataFrame as a bar chart. Make the x-axis represent the `year` and the y-axis represent the `housing_units`.
#
# 3. Style and format the line plot to ensure a professionally styled visualization.
#
# 4. Note that your resulting plot should appear similar to the following image:
#
# ![A screenshot depicts an example of the resulting bar chart.](Images/zoomed-housing-units-by-year.png)
#
# 5. Answer the following question:
#
#     * What’s the overall trend in housing units over the period that you’re analyzing?
#
# ### Calculate and Plot the Average Sale Prices per Square Foot
#
# For this part of the assignment, use numerical and visual aggregation to calculate the average prices per square foot, and then visualize the results as a bar chart. To do so, complete the following steps:
#
# 1. Group the data by year, and then average the results. What’s the lowest gross rent that’s reported for the years that the DataFrame includes?
#
# 2. Create a new DataFrame named `prices_square_foot_by_year` by filtering out the “housing_units” column. The new DataFrame should include the averages per year for only the sale price per square foot and the gross rent.
#
# 3. Use hvPlot to plot the `prices_square_foot_by_year` DataFrame as a line plot.
#
#     > **Hint** This single plot will include lines for both `sale_price_sqr_foot` and `gross_rent`.
#
# 4. Style and format the line plot to ensure a professionally styled visualization.
#
# 5. Note that your resulting plot should appear similar to the following image:
#
# ![A screenshot depicts an example of the resulting plot.](Images/avg-sale-px-sq-foot-gross-rent.png)
#
# 6. Use both the `prices_square_foot_by_year` DataFrame and interactive plots to answer the following questions:
#
#     * Did any year experience a drop in the average sale price per square foot compared to the previous year?
#
#     * If so, did the gross rent increase or decrease during that year?
#
# ### Compare the Average Sale Prices by Neighborhood
#
# For this part of the assignment, use interactive visualizations and widgets to explore the average sale price per square foot by neighborhood. To do so, complete the following steps:
#
# 1. Create a new DataFrame that groups the original DataFrame by year and neighborhood. Aggregate the results by the `mean` of the groups.
#
# 2. Filter out the “housing_units” column to create a DataFrame that includes only the `sale_price_sqr_foot` and `gross_rent` averages per year.
#
# 3. Create an interactive line plot with hvPlot that visualizes both `sale_price_sqr_foot` and `gross_rent`. Set the x-axis parameter to the year (`x="year"`). Use the `groupby` parameter to create an interactive widget for `neighborhood`.
#
# 4. Style and format the line plot to ensure a professionally styled visualization.
#
# 5. Note that your resulting plot should appear similar to the following image:
#
# ![A screenshot depicts an example of the resulting plot.](Images/pricing-info-by-neighborhood.png)
#
# 6. Use the interactive visualization to answer the following question:
#
#     * For the Anza Vista neighborhood, is the average sale price per square foot for 2016 more or less than the price that’s listed for 2012?
#
# ### Build an Interactive Neighborhood Map
#
# For this part of the assignment, explore the geospatial relationships in the data by using interactive visualizations with hvPlot and GeoViews. To build your map, use the `sfo_data_df` DataFrame (created during the initial import), which includes the neighborhood location data with the average prices. To do all this, complete the following steps:
#
# 1. Read the `neighborhood_coordinates.csv` file from the `Resources` folder into the notebook, and create a DataFrame named `neighborhood_locations_df`. Be sure to set the `index_col` of the DataFrame as “Neighborhood”.
#
# 2. Using the original `sfo_data_df` Dataframe, create a DataFrame named `all_neighborhood_info_df` that groups the data by neighborhood. Aggregate the results by the `mean` of the group.
#
# 3. Review the two code cells that concatenate the `neighborhood_locations_df` DataFrame with the `all_neighborhood_info_df` DataFrame. Note that the first cell uses the [Pandas concat function](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.concat.html) to create a DataFrame named `all_neighborhoods_df`. The second cell cleans the data and sets the “Neighborhood” column. Be sure to run these cells to create the `all_neighborhoods_df` DataFrame, which you’ll need to create the geospatial visualization.
#
# 4. Using hvPlot with GeoViews enabled, create a `points` plot for the `all_neighborhoods_df` DataFrame. Be sure to do the following:
#
#     * Set the `geo` parameter to True.
#     * Set the `size` parameter to “sale_price_sqr_foot”.
#     * Set the `color` parameter to “gross_rent”.
#     * Set the `frame_width` parameter to 700.
#     * Set the `frame_height` parameter to 500.
#     * Include a descriptive title.
#
# Note that your resulting plot should appear similar to the following image:
#
# ![A screenshot depicts an example of a scatter plot created with hvPlot and GeoViews.](Images/6-4-geoviews-plot.png)
#
# 5. Use the interactive map to answer the following question:
#
#     * Which neighborhood has the highest gross rent, and which has the highest sale price per square foot?
#
# ### Compose Your Data Story
#
# Based on the visualizations that you created, answer the following questions:
#
# * How does the trend in rental income growth compare to the trend in sales prices? Does this same trend hold true for all the neighborhoods across San Francisco?
#
# * What insights can you share with your company about the potential one-click, buy-and-rent strategy that they're pursuing? Do neighborhoods exist that you would suggest for investment, and why?

# %%
# Import the required libraries and dependencies
import pandas as pd
import hvplot.pandas
from pathlib import Path
# !pip install geoviews
import geoviews as gv
# !pip install jupyter_bokeh
# Out:
# Requirement already satisfied: geoviews in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (1.10.0)
# Requirement already satisfied: cartopy>=0.18.0 in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from geoviews) (0.21.1)
# Requirement already satisfied: panel>=1.0.0 in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from geoviews) (1.0.4)
# Requirement already satisfied: pyproj in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from geoviews) (3.4.1)
# Requirement already satisfied: packaging in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from geoviews) (23.0)
# Requirement already satisfied: shapely in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from geoviews) (2.0.1)
# Requirement already satisfied: bokeh<3.2.0,>=3.1.0 in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from geoviews) (3.1.1)
# Requirement already satisfied: holoviews>=1.16.0 in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from geoviews) (1.16.0)
# Requirement already satisfied: param in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from geoviews) (1.13.0)
# Requirement already satisfied: numpy in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from geoviews) (1.24.3)
# Requirement already satisfied: contourpy>=1 in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from bokeh<3.2.0,>=3.1.0->geoviews) (1.0.7)
# Requirement already satisfied: tornado>=5.1 in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from bokeh<3.2.0,>=3.1.0->geoviews) (6.2)
# Requirement already satisfied: pandas>=1.2 in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from bokeh<3.2.0,>=3.1.0->geoviews) (2.0.2)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from bokeh<3.2.0,>=3.1.0->geoviews) (9.4.0)
# Requirement already satisfied: xyzservices>=2021.09.1 in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from bokeh<3.2.0,>=3.1.0->geoviews) (2023.5.0)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from bokeh<3.2.0,>=3.1.0->geoviews) (6.0)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from bokeh<3.2.0,>=3.1.0->geoviews) (3.1.2)
# Requirement already satisfied: pyshp>=2.1 in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from cartopy>=0.18.0->geoviews) (2.1.3)
# Requirement already satisfied: matplotlib>=3.1 in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from cartopy>=0.18.0->geoviews) (3.7.1)
# Requirement already satisfied: pyviz-comms>=0.7.4 in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from holoviews>=1.16.0->geoviews) (2.2.1)
# Requirement already satisfied: colorcet in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from holoviews>=1.16.0->geoviews) (3.0.1)
# Requirement already satisfied: requests in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (2.29.0)
# Requirement already satisfied: markdown in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (3.4.3)
# Requirement already satisfied: typing-extensions in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (4.5.0)
# Requirement already satisfied: markdown-it-py in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (2.2.0)
# Requirement already satisfied: bleach in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (6.0.0)
# Requirement already satisfied: tqdm>=4.48.0 in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (4.65.0)
# Requirement already satisfied: mdit-py-plugins in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (0.3.5)
# Requirement already satisfied: linkify-it-py in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from panel>=1.0.0->geoviews) (2.0.2)
# Requirement already satisfied: certifi in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from pyproj->geoviews) (2023.5.7)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from Jinja2>=2.9->bokeh<3.2.0,>=3.1.0->geoviews) (2.1.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from matplotlib>=3.1->cartopy>=0.18.0->geoviews) (4.39.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from matplotlib>=3.1->cartopy>=0.18.0->geoviews) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from matplotlib>=3.1->cartopy>=0.18.0->geoviews) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from matplotlib>=3.1->cartopy>=0.18.0->geoviews) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from matplotlib>=3.1->cartopy>=0.18.0->geoviews) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from pandas>=1.2->bokeh<3.2.0,>=3.1.0->geoviews) (2023.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from pandas>=1.2->bokeh<3.2.0,>=3.1.0->geoviews) (2022.7)
# Requirement already satisfied: colorama in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from tqdm>=4.48.0->panel>=1.0.0->geoviews) (0.4.6)
# Requirement already satisfied: six>=1.9.0 in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from bleach->panel>=1.0.0->geoviews) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from bleach->panel>=1.0.0->geoviews) (0.5.1)
# Requirement already satisfied: pyct>=0.4.4 in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from colorcet->holoviews>=1.16.0->geoviews) (0.5.0)
# Requirement already satisfied: uc-micro-py in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from linkify-it-py->panel>=1.0.0->geoviews) (1.0.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from markdown-it-py->panel>=1.0.0->geoviews) (0.1.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from requests->panel>=1.0.0->geoviews) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from requests->panel>=1.0.0->geoviews) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from requests->panel>=1.0.0->geoviews) (2.0.4)
# Requirement already satisfied: jupyter_bokeh in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (3.0.7)
# Requirement already satisfied: ipywidgets==8.* in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from jupyter_bokeh) (8.0.6)
# Requirement already satisfied: bokeh==3.* in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from jupyter_bokeh) (3.1.1)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from bokeh==3.*->jupyter_bokeh) (6.0)
# Requirement already satisfied: contourpy>=1 in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from bokeh==3.*->jupyter_bokeh) (1.0.7)
# Requirement already satisfied: xyzservices>=2021.09.1 in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from bokeh==3.*->jupyter_bokeh) (2023.5.0)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from bokeh==3.*->jupyter_bokeh) (3.1.2)
# Requirement already satisfied: numpy>=1.16 in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from bokeh==3.*->jupyter_bokeh) (1.24.3)
# Requirement already satisfied: packaging>=16.8 in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from bokeh==3.*->jupyter_bokeh) (23.0)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from bokeh==3.*->jupyter_bokeh) (9.4.0)
# Requirement already satisfied: pandas>=1.2 in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from bokeh==3.*->jupyter_bokeh) (2.0.2)
# Requirement already satisfied: tornado>=5.1 in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from bokeh==3.*->jupyter_bokeh) (6.2)
# Requirement already satisfied: widgetsnbextension~=4.0.7 in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from ipywidgets==8.*->jupyter_bokeh) (4.0.7)
# Requirement already satisfied: jupyterlab-widgets~=3.0.7 in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from ipywidgets==8.*->jupyter_bokeh) (3.0.7)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from ipywidgets==8.*->jupyter_bokeh) (6.22.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from ipywidgets==8.*->jupyter_bokeh) (5.7.1)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from ipywidgets==8.*->jupyter_bokeh) (8.12.0)
# Requirement already satisfied: pyzmq>=20 in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==8.*->jupyter_bokeh) (25.0.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==8.*->jupyter_bokeh) (1.6.6)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==8.*->jupyter_bokeh) (5.3.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==8.*->jupyter_bokeh) (0.1.3)
# Requirement already satisfied: psutil in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==8.*->jupyter_bokeh) (5.9.0)
# Requirement already satisfied: nest-asyncio in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==8.*->jupyter_bokeh) (1.5.6)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==8.*->jupyter_bokeh) (0.1.6)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==8.*->jupyter_bokeh) (7.3.4)
# Requirement already satisfied: pickleshare in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (0.18.2)
# Requirement already satisfied: decorator in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (5.1.1)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (2.15.1)
# Requirement already satisfied: colorama in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (0.4.6)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (3.0.38)
# Requirement already satisfied: stack-data in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (0.6.2)
# Requirement already satisfied: backcall in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (0.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from Jinja2>=2.9->bokeh==3.*->jupyter_bokeh) (2.1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from pandas>=1.2->bokeh==3.*->jupyter_bokeh) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from pandas>=1.2->bokeh==3.*->jupyter_bokeh) (2022.7)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from pandas>=1.2->bokeh==3.*->jupyter_bokeh) (2023.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (0.8.3)
# Requirement already satisfied: entrypoints in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets==8.*->jupyter_bokeh) (0.4)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets==8.*->jupyter_bokeh) (2.5.2)
# Requirement already satisfied: pywin32>=300 in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets==8.*->jupyter_bokeh) (305.1)
# Requirement already satisfied: wcwidth in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (0.2.6)
# Requirement already satisfied: six>=1.5 in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.2->bokeh==3.*->jupyter_bokeh) (1.16.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (2.2.1)
# Requirement already satisfied: pure-eval in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (0.2.2)
# Requirement already satisfied: executing>=1.2.0 in c:\users\aaron.bunting\appdata\local\anaconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets==8.*->jupyter_bokeh) (1.2.0)

# %% [markdown]
# ## Import the data

# %%
# Using the read_csv function and Path module, create a DataFrame 
# by importing the sfo_neighborhoods_census_data.csv file from the Resources folder
sfo_data_df = pd.read_csv('Resources/sfo_neighborhoods_census_data.csv')

# Review the first and last five rows of the DataFrame
display(sfo_data_df.head())
display(sfo_data_df.tail())
# Out:
#    year      neighborhood  sale_price_sqr_foot  housing_units  gross_rent
# 0  2010      Alamo Square           291.182945         372560        1239
# 1  2010        Anza Vista           267.932583         372560        1239
# 2  2010           Bayview           170.098665         372560        1239
# 3  2010  Buena Vista Park           347.394919         372560        1239
# 4  2010  Central Richmond           319.027623         372560        1239
#      year            neighborhood  sale_price_sqr_foot  housing_units  \
# 392  2016          Telegraph Hill           903.049771         384242
# 393  2016              Twin Peaks           970.085470         384242
# 394  2016  Van Ness/ Civic Center           552.602567         384242
# 395  2016       Visitacion Valley           328.319007         384242
# 396  2016           Westwood Park           631.195426         384242
#
#      gross_rent
# 392        4390
# 393        4390
# 394        4390
# 395        4390
# 396        4390

# %% [markdown]
# ---

# %% [markdown]
# ## Calculate and Plot the Housing Units per Year
#
# For this part of the assignment, use numerical and visual aggregation to calculate the number of housing units per year, and then visualize the results as a bar chart. To do so, complete the following steps:
#
# 1. Use the `groupby` function to group the data by year. Aggregate the results by the `mean` of the groups.
#
# 2. Use the `hvplot` function to plot the `housing_units_by_year` DataFrame as a bar chart. Make the x-axis represent the `year` and the y-axis represent the `housing_units`.
#
# 3. Style and format the line plot to ensure a professionally styled visualization.
#
# 4. Note that your resulting plot should appear similar to the following image:
#
# ![A screenshot depicts an example of the resulting bar chart.](Images/zoomed-housing-units-by-year.png)
#
# 5. Answer the following question:
#
#     * What’s the overall trend in housing units over the period that you’re analyzing?

# %% [markdown]
# ### Step 1: Use the `groupby` function to group the data by year. Aggregate the results by the `mean` of the groups.

# %%
# Create a numerical aggregation that groups the data by the year and then averages the results.
housing_units_by_year = sfo_data_df.groupby('year')['housing_units'].mean()

# Review the DataFrame
housing_units_by_year
# Out:
# year
# 2010    372560.0
# 2011    374507.0
# 2012    376454.0
# 2013    378401.0
# 2014    380348.0
# 2015    382295.0
# 2016    384242.0
# Name: housing_units, dtype: float64

# %% [markdown]
# ### Step 2: Use the `hvplot` function to plot the `housing_units_by_year` DataFrame as a bar chart. Make the x-axis represent the `year` and the y-axis represent the `housing_units`.
#
# ### Step 3: Style and format the line plot to ensure a professionally styled visualization.

# %%
# Create a visual aggregation explore the housing units by year
housing_units_by_year.hvplot.bar(
    x = 'year',
    y = 'housing_units',
    xlabel = 'Year',
    ylabel = 'Housing Units',
    title = 'Housing Units in San Francisco from 2010 to 2016',
    ylim = (370000, 385000),
).opts(yformatter = '%.0f')
# Out:
# :Bars   [year]   (housing_units)

# %% [markdown]
# ### Step 5: Answer the following question:

# %% [markdown]
# **Question:** What is the overall trend in housing_units over the period being analyzed?
#
# **Answer:** # The trend in housing units illustrated a linear consistent increase in prices over the 6 year period spanning from 2010 - 2016

# %% [markdown]
# ---

# %% [markdown]
# ## Calculate and Plot the Average Sale Prices per Square Foot
#
# For this part of the assignment, use numerical and visual aggregation to calculate the average prices per square foot, and then visualize the results as a bar chart. To do so, complete the following steps:
#
# 1. Group the data by year, and then average the results. What’s the lowest gross rent that’s reported for the years that the DataFrame includes?
#
# 2. Create a new DataFrame named `prices_square_foot_by_year` by filtering out the “housing_units” column. The new DataFrame should include the averages per year for only the sale price per square foot and the gross rent.
#
# 3. Use hvPlot to plot the `prices_square_foot_by_year` DataFrame as a line plot.
#
#     > **Hint** This single plot will include lines for both `sale_price_sqr_foot` and `gross_rent`.
#
# 4. Style and format the line plot to ensure a professionally styled visualization.
#
# 5. Note that your resulting plot should appear similar to the following image:
#
# ![A screenshot depicts an example of the resulting plot.](Images/avg-sale-px-sq-foot-gross-rent.png)
#
# 6. Use both the `prices_square_foot_by_year` DataFrame and interactive plots to answer the following questions:
#
#     * Did any year experience a drop in the average sale price per square foot compared to the previous year?
#
#     * If so, did the gross rent increase or decrease during that year?

# %% [markdown]
# ### Step 1: Group the data by year, and then average the results.

# %%
# Create a numerical aggregation by grouping the data by year and averaging the results
prices_square_foot = sfo_data_df.groupby('year')['sale_price_sqr_foot'].mean()
prices_square_foot
gross_rent = sfo_data_df.groupby('year')['gross_rent'].mean()
gross_rent

# Review the resulting DataFrame
prices_square_foot_by_year = pd.concat([prices_square_foot, gross_rent], axis = 1)
prices_square_foot_by_year
# Out:
#       sale_price_sqr_foot  gross_rent
# year
# 2010           369.344353      1239.0
# 2011           341.903429      1530.0
# 2012           399.389968      2324.0
# 2013           483.600304      2971.0
# 2014           556.277273      3528.0
# 2015           632.540352      3739.0
# 2016           697.643709      4390.0

# %% [markdown]
# **Question:** What is the lowest gross rent reported for the years included in the DataFrame?
#
# **Answer:** # The lowest gross rent was reported was $1239 in the year 2010

# %% [markdown]
# ### Step 2: Create a new DataFrame named `prices_square_foot_by_year` by filtering out the “housing_units” column. The new DataFrame should include the averages per year for only the sale price per square foot and the gross rent.

# %%
# Filter out the housing_units column, creating a new DataFrame 
# Keep only sale_price_sqr_foot and gross_rent averages per year
prices_square_foot_by_year = sfo_data_df.drop(columns = ['housing_units'])

# Review the DataFrame
prices_square_foot_by_year
# Out:
#      year            neighborhood  sale_price_sqr_foot  gross_rent
# 0    2010            Alamo Square           291.182945        1239
# 1    2010              Anza Vista           267.932583        1239
# 2    2010                 Bayview           170.098665        1239
# 3    2010        Buena Vista Park           347.394919        1239
# 4    2010        Central Richmond           319.027623        1239
# ..    ...                     ...                  ...         ...
# 392  2016          Telegraph Hill           903.049771        4390
# 393  2016              Twin Peaks           970.085470        4390
# 394  2016  Van Ness/ Civic Center           552.602567        4390
# 395  2016       Visitacion Valley           328.319007        4390
# 396  2016           Westwood Park           631.195426        4390
#
# [397 rows x 4 columns]

# %% [markdown]
# ### Step 3: Use hvPlot to plot the `prices_square_foot_by_year` DataFrame as a line plot.
#
# > **Hint** This single plot will include lines for both `sale_price_sqr_foot` and `gross_rent`
#
# ### Step 4: Style and format the line plot to ensure a professionally styled visualization.

# %%
# Plot prices_square_foot_by_year. 
# Inclued labels for the x- and y-axes, and a title.

prices_square_foot_plot = prices_square_foot.hvplot(
    x = 'year',
    y = 'sale_price_sqr_foot',
    hover_color = 'red',
).opts(yformatter = '%.0f')

gross_rent_plot = gross_rent.hvplot(
    x = 'year',
    y = 'gross_rent',
    xlabel = 'year',
    ylabel = 'Gross Rent/Sale Price per Square Foot',
    hover_color = 'blue',
).opts(yformatter = '%.0f')

prices_square_foot_by_year = prices_square_foot_plot * gross_rent_plot
prices_square_foot_by_year
# Out:
# :Overlay
#    .Curve.Sale_price_sqr_foot :Curve   [year]   (sale_price_sqr_foot)
#    .Curve.Gross_rent          :Curve   [year]   (gross_rent)

# %% [markdown]
# ### Step 6: Use both the `prices_square_foot_by_year` DataFrame and interactive plots to answer the following questions:

# %% [markdown]
# **Question:** Did any year experience a drop in the average sale price per square foot compared to the previous year?
#
# **Answer:** # There was a year where the average sale price per square foot dropped compared to the previous year, which was 2011

# %% [markdown]
# **Question:** If so, did the gross rent increase or decrease during that year?
#
# **Answer:** # Depsite the drop in sale price per square foot in 2011, the gross rent actually increased during that year

# %% [markdown]
# ---

# %% [markdown]
# ## Compare the Average Sale Prices by Neighborhood
#
# For this part of the assignment, use interactive visualizations and widgets to explore the average sale price per square foot by neighborhood. To do so, complete the following steps:
#
# 1. Create a new DataFrame that groups the original DataFrame by year and neighborhood. Aggregate the results by the `mean` of the groups.
#
# 2. Filter out the “housing_units” column to create a DataFrame that includes only the `sale_price_sqr_foot` and `gross_rent` averages per year.
#
# 3. Create an interactive line plot with hvPlot that visualizes both `sale_price_sqr_foot` and `gross_rent`. Set the x-axis parameter to the year (`x="year"`). Use the `groupby` parameter to create an interactive widget for `neighborhood`.
#
# 4. Style and format the line plot to ensure a professionally styled visualization.
#
# 5. Note that your resulting plot should appear similar to the following image:
#
# ![A screenshot depicts an example of the resulting plot.](Images/pricing-info-by-neighborhood.png)
#
# 6. Use the interactive visualization to answer the following question:
#
#     * For the Anza Vista neighborhood, is the average sale price per square foot for 2016 more or less than the price that’s listed for 2012?

# %% [markdown]
# ### Step 1: Create a new DataFrame that groups the original DataFrame by year and neighborhood. Aggregate the results by the `mean` of the groups.

# %%
# Group by year and neighborhood and then create a new dataframe of the mean values
prices_by_year_by_neighborhood = sfo_data_df.groupby(["year","neighborhood"]).mean()

# Review the DataFrame
prices_by_year_by_neighborhood
# Out:
#                              sale_price_sqr_foot  housing_units  gross_rent
# year neighborhood
# 2010 Alamo Square                     291.182945       372560.0      1239.0
#      Anza Vista                       267.932583       372560.0      1239.0
#      Bayview                          170.098665       372560.0      1239.0
#      Buena Vista Park                 347.394919       372560.0      1239.0
#      Central Richmond                 319.027623       372560.0      1239.0
# ...                                          ...            ...         ...
# 2016 Telegraph Hill                   903.049771       384242.0      4390.0
#      Twin Peaks                       970.085470       384242.0      4390.0
#      Van Ness/ Civic Center           552.602567       384242.0      4390.0
#      Visitacion Valley                328.319007       384242.0      4390.0
#      Westwood Park                    631.195426       384242.0      4390.0
#
# [397 rows x 3 columns]

# %% [markdown]
# ### Step 2: Filter out the “housing_units” column to create a DataFrame that includes only the `sale_price_sqr_foot` and `gross_rent` averages per year.

# %%
# Filter out the housing_units
prices_by_year_by_neighborhood = prices_by_year_by_neighborhood.drop(columns = ['housing_units'])


# Review the first and last five rows of the DataFrame
display(prices_by_year_by_neighborhood.head())
display(prices_by_year_by_neighborhood.tail())
# Out:
#                        sale_price_sqr_foot  gross_rent
# year neighborhood
# 2010 Alamo Square               291.182945      1239.0
#      Anza Vista                 267.932583      1239.0
#      Bayview                    170.098665      1239.0
#      Buena Vista Park           347.394919      1239.0
#      Central Richmond           319.027623      1239.0
#                              sale_price_sqr_foot  gross_rent
# year neighborhood
# 2016 Telegraph Hill                   903.049771      4390.0
#      Twin Peaks                       970.085470      4390.0
#      Van Ness/ Civic Center           552.602567      4390.0
#      Visitacion Valley                328.319007      4390.0
#      Westwood Park                    631.195426      4390.0

# %% [markdown]
# ### Step 3: Create an interactive line plot with hvPlot that visualizes both `sale_price_sqr_foot` and `gross_rent`. Set the x-axis parameter to the year (`x="year"`). Use the `groupby` parameter to create an interactive widget for `neighborhood`.
#
# ### Step 4: Style and format the line plot to ensure a professionally styled visualization.

# %%
# Use hvplot to create an interactive line plot of the average price per square foot
# The plot should have a dropdown selector for the neighborhood

prices_by_year_by_neighborhood.hvplot.line(
    x='year',
    groupby='neighborhood',
    xlabel='year',
    ylabel='Gross Rent / Sale Price Per Square Foot',
    title = "Sale Price Per Square Foot and Average Gross Rent - 2010 -2016 - By neighborhood"
)
# Out:
# BokehModel(combine_events=True, render_bundle={'docs_json': {'6c069ea5-b4cc-443d-91d5-b590f645803f': {'version…

# %% [markdown]
# ### Step 6: Use the interactive visualization to answer the following question:

# %% [markdown]
# **Question:** For the Anza Vista neighborhood, is the average sale price per square foot for 2016 more or less than the price that’s listed for 2012?
#
# **Answer:** # The Anza Vista neighborhood experienced a significant decrease in the average sale price per square foot between 2012 and 2016. Specifically, the average sale price per square foot in 2016 was noticeably lower than the price in 2012

# %% [markdown]
# ---

# %% [markdown]
# ## Build an Interactive Neighborhood Map
#
# For this part of the assignment, explore the geospatial relationships in the data by using interactive visualizations with hvPlot and GeoViews. To build your map, use the `sfo_data_df` DataFrame (created during the initial import), which includes the neighborhood location data with the average prices. To do all this, complete the following steps:
#
# 1. Read the `neighborhood_coordinates.csv` file from the `Resources` folder into the notebook, and create a DataFrame named `neighborhood_locations_df`. Be sure to set the `index_col` of the DataFrame as “Neighborhood”.
#
# 2. Using the original `sfo_data_df` Dataframe, create a DataFrame named `all_neighborhood_info_df` that groups the data by neighborhood. Aggregate the results by the `mean` of the group.
#
# 3. Review the two code cells that concatenate the `neighborhood_locations_df` DataFrame with the `all_neighborhood_info_df` DataFrame. Note that the first cell uses the [Pandas concat function](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.concat.html) to create a DataFrame named `all_neighborhoods_df`. The second cell cleans the data and sets the “Neighborhood” column. Be sure to run these cells to create the `all_neighborhoods_df` DataFrame, which you’ll need to create the geospatial visualization.
#
# 4. Using hvPlot with GeoViews enabled, create a `points` plot for the `all_neighborhoods_df` DataFrame. Be sure to do the following:
#
#     * Set the `size` parameter to “sale_price_sqr_foot”.
#
#     * Set the `color` parameter to “gross_rent”.
#
#     * Set the `size_max` parameter to “25”.
#
#     * Set the `zoom` parameter to “11”.
#
# Note that your resulting plot should appear similar to the following image:
#
# ![A screenshot depicts an example of a scatter plot created with hvPlot and GeoViews.](Images/6-4-geoviews-plot.png)
#
# 5. Use the interactive map to answer the following question:
#
#     * Which neighborhood has the highest gross rent, and which has the highest sale price per square foot?

# %% [markdown]
# ### Step 1: Read the `neighborhood_coordinates.csv` file from the `Resources` folder into the notebook, and create a DataFrame named `neighborhood_locations_df`. Be sure to set the `index_col` of the DataFrame as “Neighborhood”.

# %%
# Load neighborhoods coordinates data
neighborhood_locations_df = pd.read_csv(("Resources/neighborhoods_coordinates.csv"), index_col = "Neighborhood")

# Review the DataFrame
neighborhood_locations_df
# Out:
#                           Lat         Lon
# Neighborhood
# Alamo Square        37.791012 -122.402100
# Anza Vista          37.779598 -122.443451
# Bayview             37.734670 -122.401060
# Bayview Heights     37.728740 -122.410980
# Bernal Heights      37.728630 -122.443050
# ...                       ...         ...
# West Portal         37.740260 -122.463880
# Western Addition    37.792980 -122.435790
# Westwood Highlands  37.734700 -122.456854
# Westwood Park       37.734150 -122.457000
# Yerba Buena         37.792980 -122.396360
#
# [73 rows x 2 columns]

# %% [markdown]
# ### Step 2: Using the original `sfo_data_df` Dataframe, create a DataFrame named `all_neighborhood_info_df` that groups the data by neighborhood. Aggregate the results by the `mean` of the group.

# %%
# Calculate the mean values for each neighborhood
all_neighborhood_info_df = sfo_data_df.groupby(['neighborhood']).mean()

# Review the resulting DataFrame
all_neighborhood_info_df
# Out:
#                            year  sale_price_sqr_foot  housing_units  \
# neighborhood
# Alamo Square        2013.000000           366.020712      378401.00
# Anza Vista          2013.333333           373.382198      379050.00
# Bayview             2012.000000           204.588623      376454.00
# Bayview Heights     2015.000000           590.792839      382295.00
# Bernal Heights      2013.500000           576.746488      379374.50
# ...                         ...                  ...            ...
# West Portal         2012.250000           498.488485      376940.75
# Western Addition    2012.500000           307.562201      377427.50
# Westwood Highlands  2012.000000           533.703935      376454.00
# Westwood Park       2015.000000           687.087575      382295.00
# Yerba Buena         2012.500000           576.709848      377427.50
#
#                      gross_rent
# neighborhood
# Alamo Square        2817.285714
# Anza Vista          3031.833333
# Bayview             2318.400000
# Bayview Heights     3739.000000
# Bernal Heights      3080.333333
# ...                         ...
# West Portal         2515.500000
# Western Addition    2555.166667
# Westwood Highlands  2250.500000
# Westwood Park       3959.000000
# Yerba Buena         2555.166667
#
# [73 rows x 4 columns]

# %% [markdown]
# ### Step 3: Review the two code cells that concatenate the `neighborhood_locations_df` DataFrame with the `all_neighborhood_info_df` DataFrame.
#
# Note that the first cell uses the [Pandas concat function](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.concat.html) to create a DataFrame named `all_neighborhoods_df`.
#
# The second cell cleans the data and sets the “Neighborhood” column.
#
# Be sure to run these cells to create the `all_neighborhoods_df` DataFrame, which you’ll need to create the geospatial visualization.

# %%
# Using the Pandas `concat` function, join the 
# neighborhood_locations_df and the all_neighborhood_info_df DataFrame
# The axis of the concatenation is "columns".
# The concat function will automatially combine columns with
# identical information, while keeping the additional columns.
all_neighborhoods_df = pd.concat(
    [neighborhood_locations_df, all_neighborhood_info_df], 
    axis="columns",
    sort=False
)

# Review the resulting DataFrame
display(all_neighborhoods_df.head())
display(all_neighborhoods_df.tail())
# Out:
#                        Lat         Lon         year  sale_price_sqr_foot  \
# Alamo Square     37.791012 -122.402100  2013.000000           366.020712
# Anza Vista       37.779598 -122.443451  2013.333333           373.382198
# Bayview          37.734670 -122.401060  2012.000000           204.588623
# Bayview Heights  37.728740 -122.410980  2015.000000           590.792839
# Bernal Heights   37.728630 -122.443050          NaN                  NaN
#
#                  housing_units   gross_rent
# Alamo Square          378401.0  2817.285714
# Anza Vista            379050.0  3031.833333
# Bayview               376454.0  2318.400000
# Bayview Heights       382295.0  3739.000000
# Bernal Heights             NaN          NaN
#                       Lat        Lon    year  sale_price_sqr_foot  \
# Yerba Buena      37.79298 -122.39636  2012.5           576.709848
# Bernal Heights        NaN        NaN  2013.5           576.746488
# Downtown              NaN        NaN  2013.0           391.434378
# Ingleside             NaN        NaN  2012.5           367.895144
# Outer Richmond        NaN        NaN  2013.0           473.900773
#
#                  housing_units   gross_rent
# Yerba Buena           377427.5  2555.166667
# Bernal Heights        379374.5  3080.333333
# Downtown              378401.0  2817.285714
# Ingleside             377427.5  2509.000000
# Outer Richmond        378401.0  2817.285714

# %%
# Call the dropna function to remove any neighborhoods that do not have data
all_neighborhoods_df = all_neighborhoods_df.reset_index().dropna()

# Rename the "index" column as "Neighborhood" for use in the Visualization
all_neighborhoods_df = all_neighborhoods_df.rename(columns={"index": "Neighborhood"})

# Review the resulting DataFrame
display(all_neighborhoods_df.head())
display(all_neighborhoods_df.tail())
# Out:
#        Neighborhood        Lat         Lon         year  sale_price_sqr_foot  \
# 0      Alamo Square  37.791012 -122.402100  2013.000000           366.020712
# 1        Anza Vista  37.779598 -122.443451  2013.333333           373.382198
# 2           Bayview  37.734670 -122.401060  2012.000000           204.588623
# 3   Bayview Heights  37.728740 -122.410980  2015.000000           590.792839
# 5  Buena Vista Park  37.768160 -122.439330  2012.833333           452.680591
#
#    housing_units   gross_rent
# 0       378401.0  2817.285714
# 1       379050.0  3031.833333
# 2       376454.0  2318.400000
# 3       382295.0  3739.000000
# 5       378076.5  2698.833333
#           Neighborhood       Lat         Lon     year  sale_price_sqr_foot  \
# 68         West Portal  37.74026 -122.463880  2012.25           498.488485
# 69    Western Addition  37.79298 -122.435790  2012.50           307.562201
# 70  Westwood Highlands  37.73470 -122.456854  2012.00           533.703935
# 71       Westwood Park  37.73415 -122.457000  2015.00           687.087575
# 72         Yerba Buena  37.79298 -122.396360  2012.50           576.709848
#
#     housing_units   gross_rent
# 68      376940.75  2515.500000
# 69      377427.50  2555.166667
# 70      376454.00  2250.500000
# 71      382295.00  3959.000000
# 72      377427.50  2555.166667

# %% [markdown]
# ### Step 4: Using hvPlot with GeoViews enabled, create a `points` plot for the `all_neighborhoods_df` DataFrame. Be sure to do the following:
#
# * Set the `geo` parameter to True.
# * Set the `size` parameter to “sale_price_sqr_foot”.
# * Set the `color` parameter to “gross_rent”.
# * Set the `frame_width` parameter to 700.
# * Set the `frame_height` parameter to 500.
# * Include a descriptive title.

# %%
# Create a plot to analyze neighborhood info
all_neighborhoods_df.hvplot.points(
    "Lon",
    "Lat",
    geo = True,
    size = "sale_price_sqr_foot",
    color = 'gross_rent',
    tiles = 'OSM',
    frame_width = 700,
    frame_height = 500,
    title = "Sale Price Per Square Foot and Average Gross Rent - 2010-2016 - By Neighborhood Map")
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lon,Lat]   (gross_rent,sale_price_sqr_foot)

# %% [markdown]
# ### Step 5: Use the interactive map to answer the following question:

# %% [markdown]
# **Question:** Which neighborhood has the highest gross rent, and which has the highest sale price per square foot?
#
# **Answer:** # YOUR ANSWER HERE

# %% [markdown]
# ## Compose Your Data Story
#
# Based on the visualizations that you have created, compose a data story that synthesizes your analysis by answering the following questions:

# %% [markdown]
# **Question:**  How does the trend in rental income growth compare to the trend in sales prices? Does this same trend hold true for all the neighborhoods across San Francisco?
#
# **Answer:**  # Rental income in San Francisco has consistently surpassed the growth in sales prices, and this trend is prevalent across most neighborhoods in the city. Futhermore, despite a decline in the average sale price in 2011 and the drops in sale prices observed in many neighborhoods between 2014 and 2016, the gross rent exhibited exponetial growth.

# %% [markdown]
# **Question:** What insights can you share with your company about the potential one-click, buy-and-rent strategy that they're pursuing? Do neighborhoods exist that you would suggest for investment, and why?
#
# **Answer:** # Proptech's one-click, buy and rent strategy holds great promise in San Fran, particularly for investors seeking a timely and effecient process that can lead to faster return on investment. In this regard, neighborhoods like Outer Mission, Anza Vista, Park North, and several others present worthwhile investment opportunities. These neighborhoods have experienced a downward trend in sale prices in recent years. While the growth in rental income has remained unaffected, making them even more attractive for potential investors.
